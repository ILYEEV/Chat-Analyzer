# %%
import numpy as np

# %%
import pip
# !pip install tqdm
# Out:
# ...
# dyld: lazy symbol binding failed: Symbol not found: _fdopendir$INODE64
#   Referenced from: /Users/anna/anaconda3/bin/python
#   Expected in: /usr/lib/libSystem.B.dylib
#
# dyld: Symbol not found: _fdopendir$INODE64
#   Referenced from: /Users/anna/anaconda3/bin/python
#   Expected in: /usr/lib/libSystem.B.dylib

# %%
from tqdm import tqdm

# %%
import pandas as pd
negative_tweets = pd.read_csv('negative работающий.csv', sep=';', error_bad_lines=False)
positive_tweets = pd.read_csv('negative работающий.csv', sep=';', error_bad_lines=False)

# %%
positive_tweets
# Out:
#         408906692374446080  1386325927  pleease_shut_up  \
# 0       408906692693221377  1386325927  alinakirpicheva
# 1       408906695083954177  1386325927        EvgeshaRe
# 2       408906695356973056  1386325927    ikonnikova_21
# 3       408906761416867842  1386325943        JumpyAlex
# 4       408906761769598976  1386325943  JustinB94262583
# 5       408906762436481024  1386325943       twinkleAYO
# 6       408906764114206720  1386325944      pycalyruhog
# 7       408906764608749568  1386325944        grishintv
# 8       408906765841870848  1386325944        alina_612
# 9       408906765896785920  1386325944       anvaharpew
# 10      408906815125340160  1386325956     kazerepiconu
# 11      408906818287828993  1386325957       Dane_Rider
# 12      408906819084754944  1386325957      Eugenia_lev
# 13      408906820019712002  1386325957   Vitaliy_Ivanov
# 14      408906854383620096  1386325965          __Brad_
# 15      408906854803451904  1386325965       fantanshik
# ...

# %%
positive_tweets = positive_tweets.rename(columns={'@first_timee хоть я и школота, но поверь, у нас то же самое :D общество профилирующий предмет типа)' : 'text', '1' : 'type'})

# %%
negative_tweets = negative_tweets.rename(columns={'на работе был полный пиддес :| и так каждое закрытие месяца, я же свихнусь так D:': 'text', '-1': 'type'})

# %%
import re
def to_lower_letters(text):
    text = text.str.lower()
    text = text.str.replace(' ','ЫЖЫШ')
    text = text.str.replace(r'[^А-Яа-я]','')
    text = text.str.replace('ЫЖЫШ',' ')
    return text

# %%
negative_tweets["text"] = to_lower_letters(negative_tweets["text"])
positive_tweets["text"] = to_lower_letters(positive_tweets["text"])

# %%
negative = negative_tweets[["text", "type"]]
negative['type'][0:111922] = 0
negative
# Out:
# /Users/anna/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                      text  type
# 0       коллеги сидят рубятся в   а я изза долбанной в...     0
# 1                     как говорят обещаного три года ждут     0
# 2       желаю хорошего полта и удачной посадкия буду о...     0
# 3       обновил за какимто лешим  теперь не работает п...     0
# 4       котнка вчера носик разбила плакала и расстраив...     0
# 5          зашли а то он опять затихарился я прямо физ...     0
# 6               а вообще я не болею   я не выздоравливаю      0
# 7       я микрофраза  учимся срать кирпичами в режиме ...     0
# 8       я хочу с тобой помириться  но сука я гордая и ...     0
# ...

# %%
positive = positive_tweets[["text", "type"]]
positive['type'][0:111922] = 1
positive
# Out:
# /Users/anna/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                      text  type
# 0       да всетаки он немного похож на него но мой мал...     1
# 1                      ну ты идиотка я испугалась за тебя     1
# 2         кто то в углу сидит и погибает от голода а м...     1
# 3        вот что значит страшилка но блинпосмотрев все...     1
# 4                ну любишь или нет  я не знаю кто ты бля      1
# 5         ох  ну это конечно же   чтобы у нее было мно...     1
# 6           у тебя есть ухажр нет  мои уши не кто не жрт      1
# 7                  поприветствуем моего нового читателя       1
# 8                  теперь у меня есть частичка сиднея         1
# ...

# %%
itog = pd.concat([negative, positive])

# %%
itog = itog.sample(frac=1)
itog.reset_index()
itog.to_csv("train.csv", index = False, header=False)

# %%
df = pd.DataFrame()

# %%
df.from_csv("train.csv")
# Out:
# /Users/anna/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.
#                                                     0
#  в плохом смысле что волнуюсь изза всего на это...
# блиииин как же скучнохоть одной бери и иди гулять   0
# очень хорошо посидели с друзяшкамикак всегда ка...  1
# както тупо каникулы проходят летом веселее было...  0
# разделите мою боль                                  0
#  я поссорился с парнем мужем                        0
# да так и знала сука пойти на принцип что ли зад...  0
#    ещ немногоещ чутьчуть и будешь наслаждаться ...  1
# ты читалачто написано на двери  сказала маша и ...  1
# ажилтай др эрт босдог мундаг залуу шногоонууд с...  0
# ...

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
