# %%
import numpy as np

# %%
import pip
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /home/ilya/anaconda3/lib/python3.6/site-packages
# You are using pip version 9.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from tqdm import tqdm

# %%
import pandas as pd
negative_tweets = pd.read_csv('negative работающий.csv', sep=';', error_bad_lines=False)
positive_tweets = pd.read_csv('negative работающий.csv', sep=';', error_bad_lines=False)

# %%
positive_tweets
# Out:
#         408906762813579000  1386325944  dugarchikbellko  \
# 0       408906818262688000  1386325957     nugemycejela
# 1       408906858515399000  1386325966          4post21
# 2       408906914437685000  1386325980         Poliwake
# 3       408906914723295000  1386325980       capyvixowe
# 4       408906915704738000  1386325980      nunejibaduq
# 5       408906973623505000  1386325994        Donna_132
# 6       408907184160776000  1386326044         Darynka_
# 7       408907406652232000  1386326097     mejagurijope
# 8       408907447303414000  1386326107        Ira_frank
# 9       408907490869273000  1386326117   MISS_SUAREZ_A3
# 10      408907543818154000  1386326130   Yana1966yanaRu
# 11      408907543889854000  1386326130        orangKoks
# 12      408907545122996000  1386326130        DMastattt
# 13      408907643198378000  1386326153    Michella_Bona
# 14      408907777776824000  1386326186         ermokina
# 15      408907779378659000  1386326186          SerUnim
# 16      408907829701931000  1386326198           Piro32
# 17      408907937500127000  1386326224         MGilyano
# 18      408908077396939000  1386326257      bunutymoruf
# 19      408908283697574000  1386326306         Gozelkin
# 20      408908338987291000  1386326319       qiqedivarp
# 21      408908341537026000  1386326320          tu_u_ut
# 22      408908380460175000  1386326329           GDV_15
# 23      408908381941142000  1386326330    _JustcooLBoY_
# 24      408908448882262000  1386326346        kaispenis
# 25      408908492234588000  1386326356       ferinimosp
# 26      408908535456870000  1386326366  elis_aleksandra
# 27      408908536903905000  1386326367     riwanaxibiqa
# 28      408908688821211000  1386326403       K_Rei_Chan
# 29      408908823437771000  1386326435       Pol_Alenki
# ...                    ...         ...              ...
# 111892  425085262176461000  1390183198  _green_idiot_XX
# 111893  425085400315879000  1390183231      nileruxojif
# 111894  425085400898863000  1390183231    hamsterdarina
# 111895  425085497883759000  1390183255        PimenovaT
# 111896  425085498450006000  1390183255     Pro_100_Alik
# 111897  425085599767224000  1390183279        _mcbender
# 111898  425085661235147000  1390183294        IrinaIvko
# 111899  425085706760110000  1390183304      dead___fish
# 111900  425090731212935000  1390184502     thinkduclide
# 111901  425114242262774000  1390190108  my_summer_night
# 111902  425118574437740000  1390191141         yettargc
# 111903  425118618721210000  1390191151      FedoseevaDa
# 111904  425118682377777000  1390191166         gywfafuq
# 111905  425122008918028000  1390191959  westharquoschus
# 111906  425122066296472000  1390191973  _Power_Of_Dream
# 111907  425136967064363000  1390195526       Para_papa_
# 111908  425137079115608000  1390195552     fatal_mystic
# 111909  425137141040316000  1390195567    LidiyaVlasova
# 111910  425137141451330000  1390195567       fillip_ina
# 111901  @darianovitskay я всю ночь не спала,засыпала м...
# 111902  Хочу на тренюю...Но на хоккей буду ходить толь...
# 111903  Как я устала , каждый день вставать в 7 утра и...
# 111904  http://t.co/1XBDaRHabI Длинная зеленая куртка ...
# 111905  Вчера в электричке дяденька рисовал мой портре...
# 111906      Бля, еще хренотень какая-то снилась всю ночь(
# 111907      я хочу спааать, но надо ещё на биологию идти(
# 111908       Мой мальчик заболел:( http://t.co/oMSLJ7Z2IX
# 111909      @LidiyaVlasova это точно ( походу давление ((
# 111910  RT @Russia_calls: Шлегель забанил за это((  ht...
# 111911  @alginova96 @Betyasso в школу все таки я пошла...
# 111912  @ivanenko14 и у меня также, только будильник е...
# 111913  Когда же я вернусь к тебе(( http://t.co/36qnCO...
# 111914  RT @qelasocadij: Скажите пожалуйста, как у чел...
# 111915  У нас физ ра на улице\nПака линт:(\nЧерез 45 м...
# 111916  Нас сегодня отказались принять в сад, типа мы ...
# 111917  Но не каждый хочет что то исправлять:( http://...
# 111918  скучаю так :-( только @taaannyaaa вправляет мо...
# 111919          Вот и в школу, в говно это идти уже надо(
# 111920  RT @_Them__: @LisaBeroud Тауриэль, не грусти :...
# 111921  Такси везет меня на работу. Раздумываю приплат...
#
#         -1  0  0.1  0.2   8064   111    94   2
# 0       -1  0    0    0     26    42    39   0
# 1       -1  0    0    0    718    49   249   0
# 2       -1  0    0    0  10628   207   200   0
# 3       -1  0    0    0     35    17    34   0
# 4       -1  0    0    0    222    62    62   0
# 5       -1  0    0    0   8311    36    68   0
# 6       -1  0    0    0      7    43    33   1
# 7       -1  0    0    0      8     5     3   0
# 8       -1  0    0    0   5475   244    95   1
# 9       -1  0    0    0     15     9    39   0
# 10      -1  0    0    0     16     2    14   0
# 11      -1  0    0    0     42     9    46   0
# 12      -1  0    0    0   1883    64    60   0
# 13      -1  0    0    0   7483   218    45   4
# 14      -1  0    0    0    349     6    12   0
# 15      -1  0    0    0  51622  1221   776  88
# 16      -1  0    0    0    189    22    73   0
# 17      -1  0    0    0   1340   235   465   1
# 18      -1  0    0    0     46    33    33   0
# 19      -1  0    0    0    460    18    26   0
# 20      -1  0    0    0     29    19    15   0
# 21      -1  0    0    0  14664    86    21   1
# 22      -1  0    0    0  12212  1181   845   9
# 23      -1  0    0    0    323    52    84   0
# 24      -1  0    0    0   9274   106    51   2
# 25      -1  0    0    0     39    30    30   0
# 26      -1  0    2    0    433    15    14   0
# 27      -1  0    0    0    326    59    70   0
# 28      -1  0    0    0   2578    15    11   0
# 29      -1  0    0    0   1002   203   157   0
# ...     .. ..  ...  ...    ...   ...   ...  ..
# 111892  -1  0    0    0  10131   144   128   1
# 111893  -1  0    0    0     88    19    59   0
# 111894  -1  0    0    0     41    12    15   0
# 111895  -1  0    0    0    262    33    56   1
# 111896  -1  0    0    0    161     8    16   0
# 111897  -1  0    0    0   4430    52    38   0
# 111898  -1  0    0    0   7859   190    82   0
# 111899  -1  0    0    0   5576   105    96   0
# 111900  -1  0    0    0    240   414   210   0
# 111901  -1  0    0    0   4585   702   213   1
# 111902  -1  0    0    0      3     0     0   0
# 111903  -1  0    0    0   1073    31    15   0
# 111904  -1  0    0    0    262   100   320   0
# 111905  -1  0    0    0      2     1     2   0
# 111906  -1  0    0    0  23307   126   309   1
# 111907  -1  0    0    0    560    19    36   0
# 111908  -1  0    0    0    204   162   112   0
# 111909  -1  0    0    0    111    14    22   0
# 111910  -1  0    3    0  93460  2342  1560  58
# 111911  -1  0    0    0   6189    24    20   0
# 111912  -1  0    0    0    858   268   209   2
# 111913  -1  0    0    0    280    31    31   0
# 111914  -1  0    1    0   2168   171   132   0
# 111915  -1  0    0    0  12722   638   567   2
# 111916  -1  0    0    0   4101   166   151   6
# 111917  -1  0    0    0   1138    32    46   0
# 111918  -1  0    0    0   4822    38    32   0
# 111919  -1  0    0    1    165    13    16   0
# 111920  -1  0    1    0   2516   187   265   0
# 111921  -1  0    0    0   7778   146    66   5
#
# [111922 rows x 12 columns]

# %%
positive_tweets = positive_tweets.rename(columns={'@first_timee хоть я и школота, но поверь, у нас то же самое :D общество профилирующий предмет типа)' : 'text', '1' : 'type'})

# %%
negative_tweets = negative_tweets.rename(columns={'на работе был полный пиддес :| и так каждое закрытие месяца, я же свихнусь так D:': 'text', '-1': 'type'})

# %%
import re
def to_lower_letters(text):
    text = text.str.lower()
    text = text.str.replace(' ','ЫЖЫШ')
    text = text.str.replace(r'[^А-Яа-я]','')
    text = text.str.replace('ЫЖЫШ',' ')
    return text

# %%
negative_tweets["text"] = to_lower_letters(negative_tweets["text"])
positive_tweets["text"] = to_lower_letters(positive_tweets["text"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-7efe105b4562> in <module>()
#       1 negative_tweets["text"] = to_lower_letters(negative_tweets["text"])
# ----> 2 positive_tweets["text"] = to_lower_letters(positive_tweets["text"])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text'

# %%
negative = negative_tweets[["text", "type"]]
negative['type'][0:111922] = 0
negative

# %%
positive = positive_tweets[["text", "type"]]
positive['type'][0:111922] = 1
positive

# %%
itog = pd.concat([negative, positive])

# %%
itog = itog.sample(frac=1)
itog

# %%
...
